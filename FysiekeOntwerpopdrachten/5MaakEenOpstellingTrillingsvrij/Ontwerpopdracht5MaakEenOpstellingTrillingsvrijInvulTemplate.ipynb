# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 45     |  |
# | :-------------|:-------------|
# | Lars Mulder   | 6546862 |
# | Arjun Avhale  | 6542786 |
# | Querijn Sanson| 6562507 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 45     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 10:40-11:30 | Arjun |
# | ontwerp-eis berekenen| 10:40-12:00 | Lars, Querijn |
# | synthese | 12:00-12:30 | hele groep |
# | synthese af | 13:30-14:30 | hele groep |
# | meetplan | 14:30-15:30 | hele groep |
# | iteratie| 15:30-16:30| hele groep|
# | Pauze 1| 12:30-13:30 | hele groep |
# | Pauze 2| 15:45-16:00 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 3 |
# | hoe lang voor één meting | 1 minuut |
# | verwacht nauwkeurigheid meting | 0.4 Hz |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
f = 5 # Hz
w = 2*np.pi*f # Hz
w0 = w/2
f0 = w0/(2*np.pi)
print(f"de kantelfrequentie is {f0:.1f} Hz")
# Out:
# de kantelfrequentie is 2.5 Hz

# %%
f = np.linspace(0,20,100)
A = np.abs(1/(1-((2*np.pi*f)**2/(w0**2))))

plt.figure
plt.loglog(f,A)
plt.xlabel("$log(f_v)(Hz)$")
plt.ylabel("log($A_m/A_v)$")
plt.show()

# %%
g = 9.81 #m/s^2
d_x = g/(w0)**2
print(f"minimale waarde voor delta x= {d_x:.3f} m")
# Out:
# minimale waarde voor delta x= 0.040 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
m = np.linspace(0,5,100)
def C(m,g,d_x):
    return (m*g)/d_x

plt.plot(m,C(m,g,d_x),label = "$\Delta x$")
plt.plot(m,C(m,g,d_x*2),label = "$\Delta x$*2")
plt.plot(m,C(m,g,d_x*5),label= "$\Delta x$*5")
plt.xlabel("m(kg)")
plt.ylabel("C(N/m)")
plt.legend()
plt.savefig("d_x_grafiek")
plt.show

print(C(0.5,g,d_x*1.5))
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# <>:5: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:7: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Lars\AppData\Local\Temp\ipykernel_13896\1017944230.py:5: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(m,C(m,g,d_x),label = "$\Delta x$")
# C:\Users\Lars\AppData\Local\Temp\ipykernel_13896\1017944230.py:6: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(m,C(m,g,d_x*2),label = "$\Delta x$*2")
# C:\Users\Lars\AppData\Local\Temp\ipykernel_13896\1017944230.py:7: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(m,C(m,g,d_x*5),label= "$\Delta x$*5")
# 82.24670334241132

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - de veerconstante (C) te verkleinen
# - de massa (m) vergroten
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 6 cm = 0.06 m. Deze waarde is gekozen zodat we niet precies op de minimale $\Delta x$ willen zitten, omdat we ook een onzekerheid hebben.

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="schets_opstelling.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 0.06 m
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# ja deze waarde wordt behaald
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Het systeem kan nog ongeveer 35 cm verder uitgerekt worden voordat het niet meer linear reageert
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Ja wij gaan ervan uit dat dit voldoende zal zijn
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# oude plot
f = np.logspace(-1,1,1000)
A = np.abs(1/(1-((2*np.pi*f)**2/(w0**2))))

#nieuwe plot
m = 19.7/1000    #kg
F_v = m * g      #N
u = (18.7-10.4)/100    #m
c = F_v/u       #N/m
massa = 0.252    #kg
w_0 = np.sqrt(4*c/massa)
A_n = np.abs(1/(1-((2*np.pi*f)**2/(w_0**2))))
plt.figure
plt.loglog(f,A,"r", label = "eerste grafiek")
plt.loglog(f,A_n,"b", label = "grafiek met onze c en m")
plt.legend()
plt.xlabel("$log(f_v)(Hz)$")
plt.ylabel("log($A_m/A_v)$")
plt.savefig("grafiek2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.
f_0 = w_0/(2*np.pi)

freq = np.array([2.0, 2.9,4.2,4.9,6.0])
Amp1 = np.array([0.30,0.84,5.98,6.01,6.31])
Amp2 = np.array([0.07,0.19,0.83,0.67,0.54])
Amp = Amp2/Amp1
u_amp = 0.1
u_f = 0.4
plt.plot(freq,Amp,".b")
plt.errorbar(freq,Amp,xerr = u_f, yerr =u_amp,fmt="o",label="onzekerheid" )


m = 19.7/1000    #kg
F_v = m * g      #N
u = (18.7-10.4)/100    #m
c = F_v/u       #N/m
massa = 0.252    #kg
w_0 = np.sqrt(4*c/massa)
A_n = np.abs(1/(1-((2*np.pi*f)**2/(w_0**2))))



plt.figure
plt.loglog(f,A,"r", label = "eerste grafiek")
plt.loglog(f,A_n,"b", label = "grafiek met onze c en m")
plt.legend()
plt.xlabel("$log(f_v)(Hz)$")
plt.ylabel("log($A_m/A_v)$")
plt.savefig("grafiek2")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Er zijn 2 reden dat onze datapunten niet perfect op de verwachte lijn liggen:
# 1. de veren zijn permanent vervormd, waardoor de veerconstante veranderd is
# 2. Het systeem beweegt niet alleen maar verticaal maar ook horizontaal

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# ## leerdoel 1

# %%
#f = np.linspace(0,20,100)
A = np.abs(1/(1-((2*np.pi*f)**2/(w0**2))))

plt.figure
plt.loglog(f,A)
plt.xlabel("$log(f_v)(Hz)$")
plt.ylabel("log($A_m/A_v)$")
plt.show()

# %%
g = 9.81 #m/s^2
d_x = g/(w0)**2
print(f"minimale waarde voor delta x= {d_x:.3f} m")
# Out:
# minimale waarde voor delta x= 0.040 m

# %% [markdown]
# <img src="d_x_grafiek.png" width="400">

# %% [markdown]
# ## leerdoel 2

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - de veerconstante (C) te verkleinen
# - de massa (m) vergroten
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 6 cm = 0.06 m. Deze waarde is gekozen zodat we niet precies op de minimale $\Delta x$ willen zitten, omdat we ook een onzekerheid hebben.

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 0.06 m
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# ja deze waarde wordt behaald
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Het systeem kan nog ongeveer 35 cm verder uitgerekt worden voordat het niet meer linear reageert
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Ja wij gaan ervan uit dat dit voldoende zal zijn
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
#
# <img src="grafiek2.png" width="400">
# <img src="opstelling.jpeg" width="400">
